# %%
#theory
"""
1. What is the difference between interpreted and compiled languages
>Compiled → code converts fully before running 
Interpreted → runs line by line 

2. What is exception handling in Python
>Handling errors so program doesn’t stop suddenly.

3. What is the purpose of the finally block in exception handling
>Runs always, whether error comes or not. Used for cleanup.

4. What is logging in Python
>Saving program messages (errors/info) in a file.

5. What is the significance of the del method in Python
>Runs when object is deleted, used to free memory.

6. What is the difference between import and from ... import in Python
>import → use full module name
from → use directly function/class

7. How can you handle multiple exceptions in Python
>Use multiple except blocks or combine errors.


8. What is the purpose of the with statement when handling files in Python
>Automatically closes file after use.

9. What is the difference between multithreading and multiprocessing

>Multithreading → same memory
Multiprocessing → separate memory

10. What are the advantages of using logging in a program

>Debugging help
Saves errors
Track program

11. What is memory management in Python

>Managing memory automatically.

12. What are the basic steps involved in exception handling in Python

>try → except → else → finally

13. Why is memory management important in Python

>Avoid memory waste
Improve speed

14. What is the role of try and except in exception handling

>try → risky code
except → handle error

15. How does Python's garbage collection system work


Deletes unused objects automatically.

16. What is the purpose of the else block in exception handling

>Runs when no error happens.

17. What are the common logging levels in Python

>DEBUG, INFO, WARNING, ERROR, CRITICAL

18. What is the difference between os.fork() and multiprocessing in Python

>fork → Linux only
multiprocessing → works everywhere

19. What is the importance of closing a file in Python

>Saves memory
Prevents data loss

20. What is the difference between file.read() and file.readline() in Python

>read() → full file
readline() → one line

21. What is the logging module in Python used for>
>Used to store logs in file.

22. What is the os module in Python used for in file handling

>Used to manage files and folders.

23. What are the challenges associated with memory management in Python

>Memory leaks
Slow performance

24. How do you raise an exception manually in Python
>Use raise keyword.

25. Why is it important to use multithreading in certain applications

>To run multiple tasks faster.
"""
# Out:
# "\n1. What is the difference between interpreted and compiled languages\n\n>Compiled → code converts fully before running \nInterpreted → runs line by line \n2. What is exception handling in Python\n\n>Handling errors so program doesn’t stop suddenly.\n\n3. What is the purpose of the finally block in exception handling\n>Runs always, whether error comes or not. Used for cleanup.\n\n4. What is logging in Python\n\n>Saving program messages (errors/info) in a file.\n\n5. What is the significance of the del method in Python\n\n>Runs when object is deleted, used to free memory.\n\n6. What is the difference between import and from ... import in Python\n\n>import → use full module name\nfrom → use directly function/class\n\n7. How can you handle multiple exceptions in Python\n\n>Use multiple except blocks or combine errors.\n\n\n8. What is the purpose of the with statement when handling files in Python\n\n>Automatically closes file after use.\n\n9. What is the difference between multithreading and multiprocessing\n\n>Multithreading → same memory\nMultiprocessing → separate memory\n\n10. What are the advantages of using logging in a program\n\n>Debugging help\nSaves errors\nTrack program\n\n11. What is memory management in Python\n\n>Managing memory automatically.\n\n12. What are the basic steps involved in exception handling in Python\n\n>try → except → else → finally\n\n13. Why is memory management important in Python\n\n>Avoid memory waste\nImprove speed\n\n14. What is the role of try and except in exception handling\n\n>try → risky code\nexcept → handle error\n\n15. How does Python's garbage collection system work\n\n\nDeletes unused objects automatically.\n\n16. What is the purpose of the else block in exception handling\n\n>Runs when no error happens.\n\n17. What are the common logging levels in Python\n\n>DEBUG, INFO, WARNING, ERROR, CRITICAL\n\n18. What is the difference between os.fork() and multiprocessing in Python\n\n>fork → Linux only\nmultiprocessing → works everywhere\n\n19. What is the importance of closing a file in Python\n\n>Saves memory\nPrevents data loss\n\n20. What is the difference between file.read() and file.readline() in Python\n\n>read() → full file\nreadline() → one line\n\n21. What is the logging module in Python used for>\n>Used to store logs in file.\n\n22. What is the os module in Python used for in file handling\n\n>Used to manage files and folders.\n\n23. What are the challenges associated with memory management in Python\n\n>Memory leaks\nSlow performance\n\n24. How do you raise an exception manually in Python\n>Use raise keyword.\n\n25. Why is it important to use multithreading in certain applications\n\n>To run multiple tasks faster.\n"

# %%
#PRACTICAL QUESTIONS

# %%
#1. How can you open a file for writing in Python and write a string to it
f = open("file.txt", "w")
f.write("Hello World)
f.close()

# %%
#2. Write a Python program to read the contents of a file and print each line
f = open("file.txt", "r")
for line in f:
    print(line)
f.close()
# Out:
# Hello World

# %%
#3. How would you handle a case where the file doesn't exist while trying to open it for reading
try:
    f = open("file.txt", "r")
except FileNotFoundError:
    print("File not found)

# %%
#4. Write a Python script that reads from one file and writes its content to another file
f1 = open("file1.txt", "r")
data = f1.read()

f2 = open("file2.txt", "w")
f2.write(data)

f1.close()
f2.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 #4. Write a Python script that reads from one file and writes its content to another file
# ----> 2 f1 = open("file1.txt", "r")
#       3 data = f1.read()
#       5 f2 = open("file2.txt", "w")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\IPython\core\interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# --> 346 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file1.txt'

# %%
#5. How would you catch and handle division by zero error in Python
try:
    a = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %%
#6. Write a Python program that logs an error message to a log file when a division by zero exception occurs
import logging

logging.basicConfig(filename="log.txt"  level=logging.ERROR)

try:
    10/0
except ZeroDivisionError:
    logging.error("Division by zero error")

# %%
#7. How do you log information at different levels (INFO, ERROR, WARNING) in Python
import logging

logging.basicConfig(filename="log.txt", level=logging.DEBUG)

logging.info("This is info")
logging.warning("This is warning")
logging.error("This is error")

# %%
#8. Write a program to handle a file opening error using exception handling
try:
    f = open("file.txt", "r")
except Exception as e:
    print("Error:", e)

# %%
#9. How can you read a file line by line and store its content in a list in Python
f = open("file.txt", "r")
lines = f.readlines()
f.close()

print(lines)
# Out:
# ['Hello World']

# %%
#10. How can you append data to an existing file in Python
f = open("file.txt", "a")
f.write("New line")
f.close()

# %%
#11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist
d = {"a": 1}

try:
    print(d["b"])
except KeyError:
    print("Key not found")
# Out:
# Key not found

# %%
#12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions
try:
    a = int("abc")
    b = 10/0
except ValueError:
    print("Value error")
except ZeroDivisionError:
    print("Divide by zero")
# Out:
# Value error

# %%
#13. How would you check if a file exists before attempting to read it in Python
import os

if os.path.exists("file.txt"):
    print("File exists")
else:
    print("File not found")
# Out:
# File exists

# %%
#14. Write a program that uses the logging module to log both informational and error messages
import logging

logging.basicConfig(filename="log.txt", level=logging.DEBUG)

logging.info("Program started")

try:
    10/0
except:
    logging.error("Error occurred")

# %%
#15. Write a Python program that prints the content of a file and handles the case when the file is empty
f = open("file.txt", "r")
data = f.read()

if data == "":
    print("File is empty")
else:
    print(data)

f.close()
# Out:
# 1
# 2
# 3
# 4

# %%
#16. Demonstrate how to use memory profiling to check the memory usage of a small program
from memory_profiler import profile

@profile
def my_func():
    a = [i for i in range(1000)]
    return a

my_func()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[29], line 2
#       1 #16. Demonstrate how to use memory profiling to check the memory usage of a small program
# ----> 2 from memory_profiler import profile
#       4 @profile
#       5 def my_func():
#       6     a = [i for i in range(1000)]
#
# ModuleNotFoundError: No module named 'memory_profiler'

# %%
#17. Write a Python program to create and write a list of numbers to a file, one number per line
nums = [1,2,3,4]

f = open("file.txt", "w")
for n in nums:
    f.write(str(n) + "\n")
f.close()

# %%
#18. How would you implement a basic logging setup that logs to a file with rotation after 1MB
import logging
from logging.handlers import RotatingFileHandler

handler = RotatingFileHandler("log.txt", maxBytes=1000000, backupCount=3)
logging.basicConfig(handlers=[handler], level=logging.DEBUG)

logging.info("Test log")

# %%
#19. Write a program that handles both IndexError and KeyError using a try-except block
try:
    l = [1,2]
    print(l[5])
    d = {"a":1}
    print(d["b"])
except IndexError:
    print("Index error")
except KeyError:
    print("Key error")
# Out:
# Index error

# %%
#20. How would you open a file and read its contents using a context manager in Python
with open("file.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# 1
# 2
# 3
# 4

# %%
#21. Write a Python program that reads a file and prints the number of occurrences of a specific word
f = open("file.txt", "r")
data = f.read()

word = "python"
count = data.count(word)

print(count)
f.close()
# Out:
# 0

# %%
#22. How can you check if a file is empty before attempting to read its contents
import os

if os.path.getsize("file.txt") == 0:
    print("File is empty")

# %%
#23. Write a Python program that writes to a log file when an error occurs during file handling
import logging

logging.basicConfig(filename="log.txt", level=logging.ERROR)

try:
    f = open("file.txt", "r")
except Exception:
    logging.error("File handling error")
